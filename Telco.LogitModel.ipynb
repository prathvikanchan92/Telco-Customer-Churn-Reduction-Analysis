# %%
import pandas as pd
import numpy as np

# %%
Telco = pd.read_csv('churn.csv')
Telco
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 5512  6840-RESVB    Male              0     Yes        Yes      24
# 5513  2234-XADUH  Female              0     Yes        Yes      72
# 5514  4801-JZAZL  Female              0     Yes        Yes      11
# 5515  8361-LTMKD    Male              1     Yes         No       4
# 5516  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
Telco.shape
# Out:
# (5517, 20)

# %%
Telco = Telco.drop(['customerID'],axis = 1)
Telco.shape
# Out:
# (5517, 19)

# %%
Telco.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  Churn (Yes=1)
# count    5517.000000  5517.000000     5517.000000    5517.000000
# mean        0.197571    32.875657       76.844254       0.318289
# std         0.398203    24.593647       21.924661       0.465855
# min         0.000000     0.000000       23.450000       0.000000
# 25%         0.000000     9.000000       59.950000       0.000000
# 50%         0.000000    30.000000       79.450000       0.000000
# 75%         0.000000    56.000000       94.450000       1.000000
# max         1.000000    72.000000      118.750000       1.000000

# %%
Telco_X = Telco.iloc[:,0:18]

Telco_X
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 5512    Male              0     Yes        Yes      24          Yes
# 5513  Female              0     Yes        Yes      72          Yes
# 5514  Female              0     Yes        Yes      11           No
# 5515    Male              1     Yes         No       4          Yes
# 5516    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
Telco_X = pd.get_dummies(Telco_X)
Telco_X
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  gender_Female  gender_Male  \
# 0                 0       1           29.85              1            0
# 1                 0      34           56.95              0            1
# 2                 0       2           53.85              0            1
# 3                 0      45           42.30              0            1
# 4                 0       2           70.70              1            0
# ...             ...     ...             ...            ...          ...
# 5512              0      24           84.80              0            1
# 5513              0      72          103.20              1            0
# 5514              0      11           29.60              1            0
# 5515              1       4           74.40              0            1
# 5516              0      66          105.65              0            1
#
#       Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  PhoneService_No  \
# ...

# %%
Telco_X = Telco_X.drop(['gender_Female',"Partner_No",'Dependents_No','PhoneService_No','MultipleLines_No','InternetService_Fiber optic','OnlineSecurity_No','OnlineBackup_No','DeviceProtection_No','TechSupport_No','StreamingTV_No','StreamingMovies_No','Contract_One year','PaperlessBilling_No','PaymentMethod_Bank transfer (automatic)'], axis = 1) #need n-1 dummy variables to be incluede in model
Telco_X
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  gender_Male  Partner_Yes  \
# 0                 0       1           29.85            0            1
# 1                 0      34           56.95            1            0
# 2                 0       2           53.85            1            0
# 3                 0      45           42.30            1            0
# 4                 0       2           70.70            0            0
# ...             ...     ...             ...          ...          ...
# 5512              0      24           84.80            1            1
# 5513              0      72          103.20            0            1
# 5514              0      11           29.60            0            1
# 5515              1       4           74.40            1            1
# 5516              0      66          105.65            1            0
#
#       Dependents_Yes  PhoneService_Yes  MultipleLines_No phone service  \
# ...

# %%
y = Telco["Churn (Yes=1)"] 
X = Telco_X

# %%
import statsmodels.api as sm  

model = sm.Logit(y, X).fit()

model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.471962
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:          Churn (Yes=1)   No. Observations:                 5517
# Model:                          Logit   Df Residuals:                     5495
# Method:                           MLE   Df Model:                           21
# Date:                Sun, 26 Jul 2020   Pseudo R-squ.:                  0.2456
# Time:                        16:38:08   Log-Likelihood:                -2603.8
# converged:                       True   LL-Null:                       -3451.3
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                             coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# ...

# %%
 np.exp(model.params)
# Out:
# SeniorCitizen                            1.237290
# tenure                                   0.966518
# MonthlyCharges                           0.971454
# gender_Male                              0.987248
# Partner_Yes                              0.997189
# Dependents_Yes                           0.866011
# PhoneService_Yes                         5.212369
# MultipleLines_No phone service           4.789306
# MultipleLines_Yes                        1.592318
# InternetService_DSL                      0.197299
# OnlineSecurity_Yes                       0.787616
# OnlineBackup_Yes                         1.012920
# DeviceProtection_Yes                     1.128493
# TechSupport_Yes                          0.809624
# StreamingTV_Yes                          1.712792
# StreamingMovies_Yes                      1.737962
# Contract_Month-to-month                  1.724780
# Contract_Two year                        0.533061
# PaperlessBilling_Yes                     1.408332
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
model1 = LogisticRegression()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
model1.fit(X_train, y_train)
y_test_hat = model1.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_test_hat, normalize = True) * 100
# Out:
# C:\Users\yh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 77.41545893719807

# %%
import graphviz
from sklearn.tree import DecisionTreeClassifier, export_graphviz
model2 = DecisionTreeClassifier()
model2.fit(X, y)
tel = pd.DataFrame(X)
tel_y = pd.DataFrame(y)
feature_names=tel.columns.tolist()
feature_names1=tel_y.columns.tolist()
dot_data = export_graphviz(model2, 
                           feature_names=feature_names[0:len(feature_names)],  
                           class_names=feature_names1[0],  
                           filled=True, rounded=True,  
                           special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %%
print(feature_names[0:len(feature_names)])
model2.feature_importances_
# Out:
# ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'gender_Male', 'Partner_Yes', 'Dependents_Yes', 'PhoneService_Yes', 'MultipleLines_No phone service', 'MultipleLines_Yes', 'InternetService_DSL', 'OnlineSecurity_Yes', 'OnlineBackup_Yes', 'DeviceProtection_Yes', 'TechSupport_Yes', 'StreamingTV_Yes', 'StreamingMovies_Yes', 'Contract_Month-to-month', 'Contract_Two year', 'PaperlessBilling_Yes', 'PaymentMethod_Credit card (automatic)', 'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check']
# array([0.02107485, 0.21113062, 0.28404649, 0.02842916, 0.02888969,
#        0.02790095, 0.00252629, 0.00227997, 0.02016414, 0.04479273,
#        0.01632972, 0.02052821, 0.01797698, 0.02138378, 0.01397   ,
#        0.01420032, 0.15242851, 0.00461179, 0.02018159, 0.01381846,
#        0.01963593, 0.01369983])
